# %% [markdown]
# # Assignment 8
#
# ## Due 11/22/2025 at 11:59 PM

# %% [markdown]
# ### Background
#
# You are a data scientist at Spotify and you are trying to understand the relationships among features—particularly those that explain the popularity of songs. Complete each of the tasks as described in the questions below.
#
# ### Data
#
# Import the Spotify dataset. This contains real data from the Spotify platform about the popularity and other characteristics of songs, including:
#
# 1. *artist*: Name of the artist.
# 2. *song*: Name of the track.
# 3. *duration_ms*: Duration of the track in milliseconds.
# 4. *explicit*: The lyrics or content of a song or a music video contain one or more of the criteria which could be considered offensive or unsuitable for children.
# 5. *year*: Release year of the track.
# 6. *popularity*: The higher the value, the more popular the song is.
# 7. *danceability*: Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm
# stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
# 8. *energy*: Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity.
# 9. *key*: The key the track is in. Integers map to pitches using standard pitch class notation, e.g., 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
# 10. *loudness*: The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.
# 11. *mode*: Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.
# 12. *speechiness*: Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g., talk show, audiobook, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
# 13. *acousticness*: A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# 14. *instrumentalness*: Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
# 15. *liveness*: Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
# 16. *valence*: A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g., happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g., sad, depressed, angry).*
# 17. *tempo*: The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
# 18. *genre*: Genre of the track.

# %% [markdown]
# #### Task 1
# Import the CSV file into a Pandas DataFrame. Then check to see if any of the features have missing values. Print out the number of missing values for each feature. Then print the first five records of the DataFrame.

# %%
## Write all code for task 1 in this cell

# %% [markdown]
# #### Task 2
#
# Create a correlation matrix of all numeric features.

# %%
## Write all code for task 2 in this cell

# %% [markdown]
# #### Task 3
#
# Create an iteration that will find the strongest relationship in the matrix from Question 2. Obviously, do not count a feature's correlation with itself. Print out the strongest correlation.
#
# HINT: One way to do this is to calculate the absolute value of the column using the abs() function. If you do this, you are welcome to print the absolute value of the strongest correlation. In other words, if it is negative, it is okay to print the absolute value instead.

# %%
## Write all code for task 3 in this cell

# %% [markdown]
# #### Task 4
#
# Calculate the p-value of the correlation of each feature with popularity and print them out.

# %%
## Write all code for task 4 in this cell

# %% [markdown]
# #### Task 5
#
# Create a .scatterplot() with duration_ms on the x-axis and popularity on the y-axis. Do not create a regression line for this question.

# %%
## Write all code for task 5 in this cell

# %% [markdown]
# #### Task 6
# Create a seaborn .regplot() for the exact same relationship outlined in the question above.

# %%
## Write all code for task 6 in this cell

# %% [markdown]
# #### Task 7
#
# Remove the popularity outliers from the dataset and rerun the same analyses for task 6. Notice what changes.

# %%
## Write all code for task 7 in this cell

# %% [markdown]
# #### Task 8
# Create a .regplot() using instrumentalness as the feature (x-axis) and popularity as the label (y-axis). Calculate the regression equation and place the equation, R squared, and p-value as embedded text at the bottom right of the plot.

# %%
## Write all code for task 8 in this cell

# %% [markdown]
# #### Task 9
#
# Calculate the F stats and p-values for both measures of heteroscedasticity covered in this chapter for the relationship between instrumentalness and popularity.

# %%
## Write all code for task 9 in this cell

# %% [markdown]
# #### Task 10
#
# Are the average length of songs decreasing over time? Create a jointplot that would create a chart to help answer this question.

# %%
## Write all code for task 10 in this cell
